# %% [markdown]
# # --- CSV files ---

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %% [markdown]
# # read csv

# %%
df = pd.read_csv('C:/Users/User/Documents/workspace/D.E_FreeCodeCamp/dataEngenieerFreeCodeCamp/Covid19VacunasAgrupadas.csv')

# %% [markdown]
# #### first 5 records

# %%
df.head() #if you want 10 put (10)
# Out:
#    jurisdiccion_codigo_indec jurisdiccion_nombre  \
# 0                          6        Buenos Aires
# 1                          6        Buenos Aires
# 2                          6        Buenos Aires
# 3                          6        Buenos Aires
# 4                          6        Buenos Aires
#
#                         vacuna_nombre  dosis_unica_cantidad  \
# 0  AstraZeneca ChAdOx1 S recombinante                     0
# 1     COVISHIELD ChAdOx1nCoV COVID 19                     0
# 2                    Cansino Ad5 nCoV                 89487
# 3                        Moderna ARNm                     0
# 4           Pfizer BioNTech Comirnaty                     0
#
#    primera_dosis_cantidad  segunda_dosis_cantidad  dosis_adicional_cantidad  \
# 0                 3647659                 4021671                    833148
# 1                  251400                     382                         0
# ...

# %% [markdown]
# # remove
# #### ... remove columns

# %%
df.drop(['jurisdiccion_nombre'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    jurisdiccion_codigo_indec                       vacuna_nombre  \
# 0                          6  AstraZeneca ChAdOx1 S recombinante
# 1                          6     COVISHIELD ChAdOx1nCoV COVID 19
# 2                          6                    Cansino Ad5 nCoV
# 3                          6                        Moderna ARNm
# 4                          6           Pfizer BioNTech Comirnaty
#
#    dosis_unica_cantidad  primera_dosis_cantidad  segunda_dosis_cantidad  \
# 0                     0                 3647659                 4021671
# 1                     0                  251400                     382
# 2                 89487                       0                    7490
# 3                     0                  412552                 1223430
# 4                     0                 1368835                 1442862
#
#    dosis_adicional_cantidad  dosis_refuerzo_cantidad
# 0                    833148                  1120308
# ...

# %% [markdown]
# # rename

# %%
df.rename(columns={'jurisdiccion_codigo_indec':'j_codigo_indec'},inplace=True)

# %%
df.head()
# Out:
#    j_codigo_indec                       vacuna_nombre  dosis_unica_cantidad  \
# 0               6  AstraZeneca ChAdOx1 S recombinante                     0
# 1               6     COVISHIELD ChAdOx1nCoV COVID 19                     0
# 2               6                    Cansino Ad5 nCoV                 89487
# 3               6                        Moderna ARNm                     0
# 4               6           Pfizer BioNTech Comirnaty                     0
#
#    primera_dosis_cantidad  segunda_dosis_cantidad  dosis_adicional_cantidad  \
# 0                 3647659                 4021671                    833148
# 1                  251400                     382                         0
# 2                       0                    7490                      1530
# 3                  412552                 1223430                      3186
# 4                 1368835                 1442862                     77640
#
#    dosis_refuerzo_cantidad
# ...

# %% [markdown]
# # date format (pandas)

# %% [markdown]
# df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# # describe
# #### .describe() , .info()

# %%
df.describe()
# Out:
#        j_codigo_indec  dosis_unica_cantidad  primera_dosis_cantidad  \
# count      192.000000            192.000000            1.920000e+02
# mean        48.000000           1660.593750            2.128879e+05
# std         27.761135           7868.665826            6.194602e+05
# min          2.000000              0.000000            0.000000e+00
# 25%         25.000000              0.000000            3.520250e+03
# 50%         48.000000              0.000000            3.946800e+04
# 75%         71.000000              0.000000            1.812622e+05
# max         94.000000          89487.000000            5.938248e+06
#
#        segunda_dosis_cantidad  dosis_adicional_cantidad  \
# count            1.920000e+02                192.000000
# mean             1.945959e+05              16277.416667
# std              5.468009e+05              68836.041607
# min              0.000000e+00                  0.000000
# 25%              5.355000e+02                 31.500000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   j_codigo_indec            192 non-null    int64
#  1   vacuna_nombre             192 non-null    object
#  2   dosis_unica_cantidad      192 non-null    int64
#  3   primera_dosis_cantidad    192 non-null    int64
#  4   segunda_dosis_cantidad    192 non-null    int64
#  5   dosis_adicional_cantidad  192 non-null    int64
#  6   dosis_refuerzo_cantidad   192 non-null    int64
# dtypes: int64(6), object(1)
# memory usage: 10.6+ KB
